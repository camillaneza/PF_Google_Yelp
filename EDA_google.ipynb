# %% [markdown]
# # Exploración Archivos Google maps
# Se busca entender la naturaleza, formato y estructura que contienen los archivos de metadatada de google maps para luego realizar un proceso de ETL.

# %%
#Importamos las librerias
import pandas as pd
import numpy as np
import json

# %%
#leemos el archivo en formato json
dir = ('data\metadata-sitios/1.json')
uno = pd.read_json(dir,lines=True)

# %%
#Se observa el dataframe
uno.sample(5)
# Out:
#                                         name  \
# 238840  Latinos Barber shop and beauty salon
# 146586                         Elite Puppies
# 205233               Jaime Television Repair
# 66314                    JV Contractors, LLC
# 208028                 Earthfire Arts Studio
#
#                                                   address  \
# 238840  Latinos Barber shop and beauty salon, 12111 Lo...
# 146586      Elite Puppies, 172 Main St, Webster, MA 01570
# 205233  Jaime Television Repair, 954 E 26th St, Hialea...
# 66314   JV Contractors, LLC, 8751 Commodity Cir #7, Or...
# 208028  Earthfire Arts Studio, 438 Judah St #2313, San...
#
#                                       gmap_id description   latitude  \
# 238840  0x80c2cb86d2857131:0x9e4df3069ae2912d        None  33.917686
# 146586  0x89e41f6afda8a4b9:0xe69d373479ea113d        None  36.839520
# 205233  0x88d9afcc31021a03:0x2df97283ba96fe18        None  25.846119
# ...

# %%
#Obtenemos informacion del dataframe
uno.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 275001 entries, 0 to 275000
# Data columns (total 15 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   name              274994 non-null  object
#  1   address           264939 non-null  object
#  2   gmap_id           275001 non-null  object
#  3   description       13155 non-null   object
#  4   latitude          275001 non-null  float64
#  5   longitude         275001 non-null  float64
#  6   category          272740 non-null  object
#  7   avg_rating        275001 non-null  float64
#  8   num_of_reviews    275001 non-null  int64
#  9   price             13450 non-null   object
#  10  hours             192448 non-null  object
#  11  MISC              194972 non-null  object
#  12  state             195523 non-null  object
#  13  relative_results  238771 non-null  object
#  14  url               275001 non-null  object
# dtypes: float64(3), int64(1), object(11)
# ...

# %%
#Se decide observar la columna "Category" con detenimiento.

# %%
#Se crea la variable que nos muestre las categorias
category = uno['category'].dropna().explode()
#Se guardan las categorias unicas en la variable.
category = pd.Series(category.unique())

category
# Out:
# 0                   Pharmacy
# 1           Textile exporter
# 2          Korean restaurant
# 3               Fabric store
# 4                 Restaurant
#                 ...
# 3764    Line marking service
# 3765       Windsurfing store
# 3766       Military barracks
# 3767                Helpline
# 3768    Cane furniture store
# Length: 3769, dtype: object

# %%
#Se convierten el tipo de datos de la columna category en str
uno['category'] = uno['category'].str.replace(r' | ','',regex =True)

# %%
#se lee el domuneto numero dos
dir = ('data\metadata-sitios/2.json')
dos = pd.read_json(dir,lines = True)

# %%
#Observamos el dataframe "dos"
dos.sample(5)
# Out:
#                                name  \
# 70902    U-Haul Neighborhood Dealer
# 87403                     Topdrawer
# 66518   Best Friends Pet Cremations
# 91302      Bloomers Florist & Gifts
# 260548                  WoodmenLife
#
#                                                   address  \
# 70902   U-Haul Neighborhood Dealer, 1140 E Wine Countr...
# 87403       Topdrawer, 1815 Fourth St, Berkeley, CA 94710
# 66518   Best Friends Pet Cremations, 924 Menaul Blvd N...
# 91302   Bloomers Florist & Gifts, 12385 Old Halls Ferr...
# 260548  WoodmenLife, 112 Hollywood Dr #101, Butler, PA...
#
#                                       gmap_id description   latitude  \
# 70902   0x5498186595498f33:0x8abc1506e5008561        None  46.252712
# 87403   0x80857f3c008bddef:0xa22f37bffacf0819        None  37.869525
# 66518   0x872273542f899619:0xdbdba8531a177636        None  35.107755
# 91302   0x87df481cffc91839:0x57d09f36db6c2bea        None  38.793132
# ...

# %%
#Obtenemos la informacion del dataframe

dos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 275001 entries, 0 to 275000
# Data columns (total 15 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   name              274993 non-null  object
#  1   address           265201 non-null  object
#  2   gmap_id           275001 non-null  object
#  3   description       14111 non-null   object
#  4   latitude          275001 non-null  float64
#  5   longitude         275001 non-null  float64
#  6   category          272882 non-null  object
#  7   avg_rating        275001 non-null  float64
#  8   num_of_reviews    275001 non-null  int64
#  9   price             14401 non-null   object
#  10  hours             192124 non-null  object
#  11  MISC              197827 non-null  object
#  12  state             195942 non-null  object
#  13  relative_results  241166 non-null  object
#  14  url               275001 non-null  object
# dtypes: float64(3), int64(1), object(11)
# ...

# %%
#Se crea la variable que nos muestre las categorias
category2 = dos['category'].dropna().explode()
#Se guardan las categorias unicas en la variable.
category2 = pd.Series(category2.unique())

category2
# Out:
# 0                                 Pharmacy
# 1                           Clothing store
# 2                               Shoe store
# 3                   Women's clothing store
# 4       Handicapped transportation service
#                        ...
# 3776                     Accounting school
# 3777                 Bungee jumping center
# 3778                    City pillar shrine
# 3779                       Coat wholesaler
# 3780                 Fire fighters academy
# Length: 3781, dtype: object

# %%
#Se lee el archivo json
tres = pd.read_json('data/metadata-sitios/3.json',lines=True)

# %%
tres.sample(5)
# Out:
#                                           name  \
# 37236   D & B/Pop's Seafood & More Restaurants
# 162813                               Inked NYC
# 91211                Jake's Auto & Truck Sales
# 155946                               Mj Select
# 75655                 J. Clayton Callaway, DDS
#
#                                                   address  \
# 37236   D & B/Pop's Seafood & More Restaurants, 4084 R...
# 162813       Inked NYC, 150 W 22nd St, New York, NY 10011
# 91211   Jake's Auto & Truck Sales, 705 Gum Branch Rd, ...
# 155946  Mj Select, 6439 Ivarene Ave, Los Angeles, CA 9...
# 75655   J. Clayton Callaway, DDS, 2119 A 25th St, Colu...
#
#                                       gmap_id description   latitude  \
# 37236   0x889293276bf3f277:0xc02c802172f1491a        None  31.252641
# 162813  0x89c259d10164cb79:0xa73f91fbcdf56a35        None  40.742922
# 91211   0x89a9105ca69054dd:0xa36c59c64b2c133f        None  34.768299
# ...
