# %% [markdown]
# # ETL archivos Yelp
# El objetivo es poder entender la naturaleza, formato y estructura que conteinen los archivos de Yelp para luego realizar el proceso de ETL.
#
# * business.pkl
# * review.json
# * user.parquet
# * checkin.json
# * tip.json

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pyspark.sql import SparkSession
import pyarrow.parquet as pq
import json
import seaborn as sns

# %% [markdown]
# ## checkin

# %%
def abrir_Archivo_json(archivo):
    merged_data = []  # Lista para almacenar los objetos JSON combinados

    with open(archivo) as file:
        for line in file:
            try:
                obj = json.loads(line)
                merged_data.append(obj)
            except json.JSONDecodeError as e:
                print(f"Error al decodificar JSON en el archivo {archivo}: {str(e)}")

    df = pd.DataFrame(merged_data)  # Crear DataFrame a partir de los objetos JSON
    return df

# %%
archivo = 'data/Yelp/checkin.json' 
df_checkin_yelp = abrir_Archivo_json(archivo)

# %%
#Revisamos si tiene nulos
df_checkin_yelp.isnull().sum()
# Out:
# business_id    0
# date           0
# dtype: int64

# %%
#Revisamos si hay duplicados
df_checkin_yelp.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Desanidado de Fecha y Hora

# %%
fecha = []
for _, row in df_checkin_yelp.iterrows():
    business_id = row['business_id']
    dates = row['date'].split(', ')
    for date in dates:
        time, date = date.split(' ')
        fecha.append([business_id, time, date])

df_desanidado = pd.DataFrame(fecha,columns =['business_id','hour','date'])

# %%
df_desanidado
# Out:
#                      business_id        hour      date
# 0         ---kPU91CF4Lq2-WlRu9Lw  2020-03-13  21:10:56
# 1         ---kPU91CF4Lq2-WlRu9Lw  2020-06-02  22:18:06
# 2         ---kPU91CF4Lq2-WlRu9Lw  2020-07-24  22:42:27
# 3         ---kPU91CF4Lq2-WlRu9Lw  2020-10-24  21:36:13
# 4         ---kPU91CF4Lq2-WlRu9Lw  2020-12-09  21:23:33
# ...                          ...         ...       ...
# 13356870  zzu6_r3DxBJuXcjnOYVdTw  2013-12-11  00:52:49
# 13356871  zzu6_r3DxBJuXcjnOYVdTw  2013-12-13  00:58:14
# 13356872  zzw66H6hVjXQEt0Js3Mo4A  2016-12-03  23:33:26
# 13356873  zzw66H6hVjXQEt0Js3Mo4A  2018-12-02  19:08:45
# 13356874  zzyx5x0Z7xXWWvWnZFuxlQ  2015-01-06  17:51:53
#
# [13356875 rows x 3 columns]

# %%
#Se almacena en un csv
df_desanidado.to_csv('data/Yelp/checkin.csv',index = False)

# %% [markdown]
# ## user.parquet

# %% [markdown]
# ## business.pkl

# %%
#se lee el archivo
df_business= pd.read_pickle('data/Yelp/business.pkl')

# %%
df_business
# Out:
#                    business_id                      name  \
# 0       Pns2l4eNsfO8kk83dixA6A  Abby Rappoport, LAC, CMQ
# 1       mpf3x-BjTdTEA3yCZrAYPw             The UPS Store
# 2       tUFrWirKiKi_TAnsVWINQQ                    Target
# 3       MTSW4McQd7CbVtyjqoe9mw        St Honore Pastries
# 4       mWMc6_wTdE0EUBKIGXDVfA  Perkiomen Valley Brewery
# ...                        ...                       ...
# 150341  IUQopTMmYQG-qRtBk-8QnA              Binh's Nails
# 150342  c8GjPIOTGVmIemT7j5_SyQ      Wild Birds Unlimited
# 150343  _QAMST-NrQobXduilWEqSw         Claire's Boutique
# 150344  mtGm22y5c2UHNXDFAjaPNw  Cyclery & Fitness Center
# 150345  jV_XOycEzSlTx-65W906pg                   Sic Ink
#
#                                 address           city state postal_code  \
# 0                1616 Chapala St, Ste 2  Santa Barbara   NaN       93101
# 1       87 Grasso Plaza Shopping Center         Affton   NaN       63123
# 2                  5255 E Broadway Blvd         Tucson   NaN       85711
# 3                           935 Race St   Philadelphia    CA       19107
# 4                         101 Walnut St     Green Lane    MO       18054
# ...                                 ...            ...   ...         ...
# 150341                3388 Gateway Blvd       Edmonton    IN     T6J 5H2
# 150342               2813 Bransford Ave      Nashville    DE       37204
# 150343           6020 E 82nd St, Ste 46   Indianapolis    AB       46250
# 150344                     2472 Troy Rd   Edwardsville    AB       62025
# 150345            238 Apollo Beach Blvd   Apollo beach    TN       33572
#
#          latitude   longitude stars review_count  ... state postal_code  \
# 0       34.426679 -119.711197   5.0            7  ...   NaN         NaN
# 1       38.551126  -90.335695   3.0           15  ...   NaN         NaN
# 2       32.223236 -110.880452   3.5           22  ...   NaN         NaN
# 3       39.955505  -75.155564   4.0           80  ...   NaN         NaN
# 4       40.338183  -75.471659   4.5           13  ...   NaN         NaN
# ...           ...         ...   ...          ...  ...   ...         ...
# 150341  53.468419 -113.492054   3.0           13  ...   NaN         NaN
# 150342  36.115118  -86.766925   4.0            5  ...   NaN         NaN
# 150343  39.908707  -86.065088   3.5            8  ...   NaN         NaN
# 150344  38.782351  -89.950558   4.0           24  ...   NaN         NaN
# 150345  27.771002   -82.39491   4.5            9  ...   NaN         NaN
#
#        latitude longitude stars review_count is_open attributes categories  \
# 0           NaN       NaN   NaN          NaN     NaN        NaN        NaN
# 1           NaN       NaN   NaN          NaN     NaN        NaN        NaN
# 2           NaN       NaN   NaN          NaN     NaN        NaN        NaN
# 3           NaN       NaN   NaN          NaN     NaN        NaN        NaN
# 4           NaN       NaN   NaN          NaN     NaN        NaN        NaN
# ...         ...       ...   ...          ...     ...        ...        ...
# 150341      NaN       NaN   NaN          NaN     NaN        NaN        NaN
# 150342      NaN       NaN   NaN          NaN     NaN        NaN        NaN
# 150343      NaN       NaN   NaN          NaN     NaN        NaN        NaN
# 150344      NaN       NaN   NaN          NaN     NaN        NaN        NaN
# 150345      NaN       NaN   NaN          NaN     NaN        NaN        NaN
#
#        hours
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
# ...      ...
# 150341   NaN
# 150342   NaN
# 150343   NaN
# 150344   NaN
# 150345   NaN
#
# [150346 rows x 28 columns]

# %%
#Se agregan nuevas columnas en el Dataframe Vacias
df_business['NAME']=None
df_business['REVIEW_COUNT']=None
df_business['POSTAL_CODE']=None
df_business['CITY']=None
df_business['STATE']=None
df_business['BUSINESS_ID']=None
df_business['ADDRESS']=None
df_business['LATITUDE']=None
df_business['LONGITUDE']=None
df_business['STARS']=None
df_business['IS_OPEN']=None
df_business['ATTRIBUTES']=None
df_business['CATEGORIES']=None
df_business['HOURS']=None

# %%
#Se actualiza la columna NAME del Dataframe donde se fusionan las cadenas de texto, eliminando los caracteres no Alfabeticos
for index,i in enumerate(df_business.name.values):
    arr=[]
    for e in i:
        if isinstance(e,str):
         arr.append(e)
    df_business['NAME'][index]=''.join(arr)

# %%
# Configurar pandas para mostrar todas las columnas
pd.set_option('display.max_columns', None)

# %%
#Se actualiza la columna CITY del Dataframe donde se fusionan las cadenas de texto, eliminando los caracteres no Alfabeticos
for index,i in enumerate(df_business.city.values):
    arr=[]
    for e in i:
        if isinstance(e,str):
         arr.append(e)
    df_business['CITY'][index]=''.join(arr)

# %%
#Se actualiza la columna STATE del Dataframe donde se fusionan las cadenas de texto, eliminando los caracteres no Alfabeticos
for index,i in enumerate(df_business.state.values):
    arr=[]
    for e in i:
        if isinstance(e,str):
         arr.append(e)
    df_business['STATE'][index]=''.join(arr)

# %%
#Se actualiza la columna REVIEW_COUNT del Dataframe donde se fusionan las cadenas de texto, eliminando los caracteres no Alfabeticos
for index,i in enumerate(df_business.review_count.values):
    arr=[]
    for e in i:
        if isinstance(e,str):
         arr.append(e)
    df_business['REVIEW_COUNT'][index]=''.join(arr)

# %%
#Se actualiza la columna BUSINESS_ID del Dataframe donde se fusionan las cadenas de texto, eliminando los caracteres no Alfabeticos
for index,i in enumerate(df_business.business_id.values):
    arr=[]
    for e in i:
        if isinstance(e,str):
         arr.append(e)
    df_business['BUSINESS_ID'][index]=''.join(arr)

# %%
#Se actualiza la columna ADDRESS del Dataframe donde se fusionan las cadenas de texto, eliminando los caracteres no Alfabeticos
for index,i in enumerate(df_business.address.values):
    arr=[]
    for e in i:
        if isinstance(e,str):
         arr.append(e)
    df_business['ADDRESS'][index]=''.join(arr)

# %%
#Se actualiza la columna POSTAL_CODE del Dataframe donde se fusionan las cadenas de texto, eliminando los caracteres no Alfabeticos
for index,i in enumerate(df_business.postal_code.values):
    arr=[]
    for e in i:
        if isinstance(e,str):
         arr.append(e)
    df_business['POSTAL_CODE'][index]=''.join(arr)

# %%
#Se filtran los elementos numéricos mayores que 1 en cada valor de la columna 'latitude' del DataFrame 'df_business'.
# A continuación, se asigna el primer elemento filtrado a la columna 'LATITUDE' en el DataFrame 'df_business' en la fila
#correspondiente al índice actual.
for index,i in enumerate(df_business.latitude.values):
    arr=[]
    for e in i:
       if e>1:
         arr.append(e)
    df_business['LATITUDE'][index]=arr[0]

# %%
#Se filtran los elementos numéricos menores que -1 en cada valor de la columna 'longitude' del DataFrame 'df_business'.
#Luego, se asigna el primer elemento filtrado a la columna 'LONGITUDE' en el DataFrame 'df_business' en la fila correspondiente al
# índice actual.
for index,i in enumerate(df_business.longitude.values):
    arr=[]
    for e in i:
        if e<-1:
            arr.append(e)
    df_business['LONGITUDE'][index]=arr[0]

# %%
#Se filtran los elementos numéricos mayores que 0.1 en cada valor de la columna 'stars' del DataFrame 'df_business'.
# Después, se asigna el primer elemento filtrado a la columna 'STARS' en el DataFrame 'df_business' en la fila correspondiente 
#al índice actual.
for index,i in enumerate(df_business.stars.values):
    arr=[]
    for e in i:
       if e>0.1:
         arr.append(e)
    df_business['STARS'][index]=arr[0]

# %%
#Se filtran los elementos numéricos mayores o iguales a 0 en cada valor de la columna 'is_open' del DataFrame 'df_business'. 
#A continuación, se asigna el primer elemento filtrado a la columna 'IS_OPEN' en el DataFrame 'df_business' en la fila correspondiente al índice actual

for index,i in enumerate(df_business.is_open.values):
    arr=[]
    for e in i:
       if e >=0:
         arr.append(e)
    df_business['IS_OPEN'][index]=arr[0]

# %%
#Este código busca y guarda el primer diccionario encontrado en la columna 'attributes' del dataframe 'df_business' en la columna 'ATTRIBUTES'.
for index,i in enumerate(df_business.attributes.values):
    arr=[]
    for e in i:
        if isinstance(e,dict):
         arr.append(e)
    if len(arr)>0:
     df_business['ATTRIBUTES'][index]=arr[0]

# %%
#Este código filtra los elementos de tipo cadena en la columna 'categories' del dataframe 'df_business'. 
#Luego, fusiona todas las cadenas filtradas en una sola cadena y la asigna a la columna 'CATEGORIES' en el dataframe 'df_business'.
for index,i in enumerate(df_business.categories.values):
    arr=[]
    for e in i:
        if isinstance(e,str):
         arr.append(e)
    df_business['CATEGORIES'][index]=''.join(arr)

# %%
#En este código, se recorren los valores de la columna 'hours' en el dataframe 'df_business' y se filtran los elementos que son diccionarios. 
#Luego, se asigna el primer diccionario encontrado a la columna 'HOURS' en el dataframe 'df_business' en la fila correspondiente.
#En resumen, el código extrae y guarda el primer diccionario encontrado en la columna 'hours' del dataframe 'df_business' en la columna 'HOURS'.
for index,i in enumerate(df_business.hours.values):
    arr=[]
    for e in i:
        if isinstance(e,dict):
         arr.append(e)
    if len(arr)>0:     
     df_business['HOURS'][index]=arr[0]

# %%
df_business.sample(10)
# Out:
#                    business_id  \
# 6481    -RzbRfPnKcwTixtokN-p6A
# 144944  v2GbFKx4gxfyk_rSQK0hjQ
# 86177   yTeH-Xqp2qob651GU6aE7Q
# 112285  5HY-o1nDuR0calZpsw5qiA
# 12321   YAT0yzBf4o96xJJiWVsgNg
# 145444  s8MTunfjxZslRLcjlTiCJg
# 32553   _hBFNHhw8MHIlyNT3tuAKw
# 127300  zgZuBaWSo7wmDoHzvKNTRQ
# 78360   IeE2U3wFI1Wa0HbH4jJ2Iw
# 7845    Birks4csk8zknL5a5QCiow
#
#                                                      name  \
# 6481                                                 Cosi
# 144944  A Discount Mobile Convertible Tops and Headliners
# 86177                                       Oggi Pizzeria
# 112285                                 The Sensory Playce
# 12321                                       American Male
# 145444                                     North Star Bar
# 32553                                             Wendy's
# 127300       Erlich's Four Hour Cleaner and Shirt Laundry
# 78360                                     Esporta Fitness
# 7845                                         Mello Freeze
#
#                        address               city state postal_code  \
# 6481            215 Lombard St       Philadelphia    FL       19147
# 144944                                Palm Harbor    NJ       34682
# 86177         218 E Davis Blvd              Tampa    LA       33606
# 112285      1471 S Vinnell Way              Boise    TN       83709
# 12321             37 S 16th St       Philadelphia    FL       19102
# 145444          2639 Poplar St       Philadelphia    PA       19130
# 32553   5250 South East Street       Indianapolis    PA       46227
# 127300     1400 Washington Ave        Saint Louis    DE       63103
# 78360      2020 County Line Rd  Huntingdon Valley    MO       19006
# 7845             1437 Bond Ave   East Saint Louis    NJ       62201
#
#          latitude   longitude stars review_count is_open  \
# 6481    39.942257  -75.145956   3.5            5       0
# 144944   28.07463  -82.766556   3.5            5       1
# 86177    27.92683   -82.45381   4.5           55       0
# 112285  43.591135 -116.286784   4.0            8       1
# 12321   39.951625  -75.167058   3.0           11       0
# 145444  39.973016  -75.180598   3.5          134       0
# 32553    39.68981  -86.149301   2.5            8       1
# 127300  38.632264  -90.199838   1.0            9       0
# 78360   40.169642  -75.070149   2.0           36       1
# 7845    38.612051  -90.154869   5.0            5       1
#
#                                                attributes  \
# 6481                                                 None
# 144944  {'BusinessAcceptsCreditCards': 'False', 'WiFi'...
# 86177   {'Ambience': '{'touristy': False, 'hipster': F...
# 112285  {'WheelchairAccessible': 'True', 'BusinessAcce...
# 12321   {'ByAppointmentOnly': 'True', 'RestaurantsPric...
# 145444  {'BusinessAcceptsCreditCards': 'True', 'GoodFo...
# 32553   {'GoodForKids': 'True', 'RestaurantsReservatio...
# 127300  {'RestaurantsPriceRange2': '1', 'BusinessAccep...
# 78360   {'ByAppointmentOnly': 'False', 'GoodForKids': ...
# 7845    {'BusinessAcceptsCreditCards': 'True', 'Busine...
#
#                                                categories  \
# 6481                                   Food, Coffee & Tea
# 144944  Auto Parts & Supplies, Auto Detailing, Furnitu...
# 86177   Food, Pizza, Restaurants, Salad, International...
# 112285  Kids Activities, Active Life, Playgrounds, Ind...
# 12321               Hair Salons, Beauty & Spas, Skin Care
# 145444  Food, Arts & Entertainment, Beer, Wine & Spiri...
# 32553                     Fast Food, Restaurants, Burgers
# 127300  Dry Cleaning & Laundry, Local Services, Laundr...
# 78360   Yoga, Active Life, Fitness & Instruction, Gyms...
# 7845                      Ice Cream & Frozen Yogurt, Food
#
#                                                     hours business_id name  \
# 6481                                                 None         NaN  NaN
# 144944  {'Monday': '8:0-17:0', 'Tuesday': '8:0-17:0', ...         NaN  NaN
# 86177                               {'Monday': '0:0-0:0'}         NaN  NaN
# 112285  {'Monday': '0:0-0:0', 'Tuesday': '10:0-17:0', ...         NaN  NaN
# 12321                                                None         NaN  NaN
# 145444  {'Monday': '17:0-2:0', 'Tuesday': '17:0-2:0', ...         NaN  NaN
# 32553   {'Monday': '10:0-1:0', 'Tuesday': '10:0-1:0', ...         NaN  NaN
# 127300                                               None         NaN  NaN
# 78360   {'Monday': '0:0-0:0', 'Tuesday': '5:0-22:0', '...         NaN  NaN
# 7845    {'Monday': '12:0-21:0', 'Tuesday': '12:0-21:0'...         NaN  NaN
#
#        address city state postal_code latitude longitude stars review_count  \
# 6481       NaN  NaN   NaN         NaN      NaN       NaN   NaN          NaN
# 144944     NaN  NaN   NaN         NaN      NaN       NaN   NaN          NaN
# 86177      NaN  NaN   NaN         NaN      NaN       NaN   NaN          NaN
# 112285     NaN  NaN   NaN         NaN      NaN       NaN   NaN          NaN
# 12321      NaN  NaN   NaN         NaN      NaN       NaN   NaN          NaN
# 145444     NaN  NaN   NaN         NaN      NaN       NaN   NaN          NaN
# 32553      NaN  NaN   NaN         NaN      NaN       NaN   NaN          NaN
# 127300     NaN  NaN   NaN         NaN      NaN       NaN   NaN          NaN
# 78360      NaN  NaN   NaN         NaN      NaN       NaN   NaN          NaN
# 7845       NaN  NaN   NaN         NaN      NaN       NaN   NaN          NaN
#
#        is_open attributes categories hours  \
# 6481       NaN        NaN        NaN   NaN
# 144944     NaN        NaN        NaN   NaN
# 86177      NaN        NaN        NaN   NaN
# 112285     NaN        NaN        NaN   NaN
# 12321      NaN        NaN        NaN   NaN
# 145444     NaN        NaN        NaN   NaN
# 32553      NaN        NaN        NaN   NaN
# 127300     NaN        NaN        NaN   NaN
# 78360      NaN        NaN        NaN   NaN
# 7845       NaN        NaN        NaN   NaN
#
#                                                      NAME REVIEW_COUNT  \
# 6481                                                 Cosi
# 144944  A Discount Mobile Convertible Tops and Headliners
# 86177                                       Oggi Pizzeria
# 112285                                 The Sensory Playce
# 12321                                       American Male
# 145444                                     North Star Bar
# 32553                                             Wendy's
# 127300       Erlich's Four Hour Cleaner and Shirt Laundry
# 78360                                     Esporta Fitness
# 7845                                         Mello Freeze
#
#        POSTAL_CODE               CITY STATE             BUSINESS_ID  \
# 6481         19147       Philadelphia    FL  -RzbRfPnKcwTixtokN-p6A
# 144944       34682        Palm Harbor    NJ  v2GbFKx4gxfyk_rSQK0hjQ
# 86177        33606              Tampa    LA  yTeH-Xqp2qob651GU6aE7Q
# 112285       83709              Boise    TN  5HY-o1nDuR0calZpsw5qiA
# 12321        19102       Philadelphia    FL  YAT0yzBf4o96xJJiWVsgNg
# 145444       19130       Philadelphia    PA  s8MTunfjxZslRLcjlTiCJg
# 32553        46227       Indianapolis    PA  _hBFNHhw8MHIlyNT3tuAKw
# 127300       63103        Saint Louis    DE  zgZuBaWSo7wmDoHzvKNTRQ
# 78360        19006  Huntingdon Valley    MO  IeE2U3wFI1Wa0HbH4jJ2Iw
# 7845         62201   East Saint Louis    NJ  Birks4csk8zknL5a5QCiow
#
#                        ADDRESS   LATITUDE   LONGITUDE STARS IS_OPEN  \
# 6481            215 Lombard St  39.942257  -75.145956   3.5       0
# 144944                           28.07463  -82.766556   3.5       1
# 86177         218 E Davis Blvd   27.92683   -82.45381   4.5       0
# 112285      1471 S Vinnell Way  43.591135 -116.286784   4.0       1
# 12321             37 S 16th St  39.951625  -75.167058   3.0       0
# 145444          2639 Poplar St  39.973016  -75.180598   3.5       0
# 32553   5250 South East Street   39.68981  -86.149301   2.5       1
# 127300     1400 Washington Ave  38.632264  -90.199838   1.0       0
# 78360      2020 County Line Rd  40.169642  -75.070149   2.0       1
# 7845             1437 Bond Ave  38.612051  -90.154869   5.0       1
#
#                                                ATTRIBUTES  \
# 6481                                                 None
# 144944  {'BusinessAcceptsCreditCards': 'False', 'WiFi'...
# 86177   {'Ambience': '{'touristy': False, 'hipster': F...
# 112285  {'WheelchairAccessible': 'True', 'BusinessAcce...
# 12321   {'ByAppointmentOnly': 'True', 'RestaurantsPric...
# 145444  {'BusinessAcceptsCreditCards': 'True', 'GoodFo...
# 32553   {'GoodForKids': 'True', 'RestaurantsReservatio...
# 127300  {'RestaurantsPriceRange2': '1', 'BusinessAccep...
# 78360   {'ByAppointmentOnly': 'False', 'GoodForKids': ...
# 7845    {'BusinessAcceptsCreditCards': 'True', 'Busine...
#
#                                                CATEGORIES  \
# 6481                                   Food, Coffee & Tea
# 144944  Auto Parts & Supplies, Auto Detailing, Furnitu...
# 86177   Food, Pizza, Restaurants, Salad, International...
# 112285  Kids Activities, Active Life, Playgrounds, Ind...
# 12321               Hair Salons, Beauty & Spas, Skin Care
# 145444  Food, Arts & Entertainment, Beer, Wine & Spiri...
# 32553                     Fast Food, Restaurants, Burgers
# 127300  Dry Cleaning & Laundry, Local Services, Laundr...
# 78360   Yoga, Active Life, Fitness & Instruction, Gyms...
# 7845                      Ice Cream & Frozen Yogurt, Food
#
#                                                     HOURS
# 6481                                                 None
# 144944  {'Monday': '8:0-17:0', 'Tuesday': '8:0-17:0', ...
# 86177                               {'Monday': '0:0-0:0'}
# 112285  {'Monday': '0:0-0:0', 'Tuesday': '10:0-17:0', ...
# 12321                                                None
# 145444  {'Monday': '17:0-2:0', 'Tuesday': '17:0-2:0', ...
# 32553   {'Monday': '10:0-1:0', 'Tuesday': '10:0-1:0', ...
# 127300                                               None
# 78360   {'Monday': '0:0-0:0', 'Tuesday': '5:0-22:0', '...
# 7845    {'Monday': '12:0-21:0', 'Tuesday': '12:0-21:0'...

# %%
df_business.to_csv('data/Yelp/business.csv',index = False)

# %%
dtypes = {'col14': str, 'col15': str, 'col16': str, 'col17': str, 'col18': str, 'col19': str, 'col25': str, 'col26': str, 'col27': str}
df_business = pd.read_csv('data/Yelp/business.csv', dtype=dtypes)

# %%
#Filtramos el dataframe solo a las columnas nuevas generadas con los bucles, con los nombres iniciales

# %%
# Obtén la lista de todas las columnas
all_columns = df_business.columns

# Itera sobre todas las columnas y aplica el método .loc
for col in all_columns:
    df_business.loc[:, col] = df_business[col]

# %%
df_business = df_business[['BUSINESS_ID', 'NAME', 'REVIEW_COUNT', 'CITY', 'STATE', 'ADDRESS', 'POSTAL_CODE', 'LATITUDE', 'LONGITUDE', 'STARS', 'IS_OPEN', 'ATTRIBUTES', 'CATEGORIES', 'HOURS']]

df_business.loc[:, 'business_id'] = df_business['BUSINESS_ID']
df_business.loc[:, 'name'] = df_business['NAME']
df_business.loc[:, 'address'] = df_business['ADDRESS']
df_business.loc[:, 'city'] = df_business['CITY']
df_business.loc[:, 'state'] = df_business['STATE']
df_business.loc[:, 'postal_code'] = df_business['POSTAL_CODE']
df_business.loc[:, 'latitude'] = df_business['LATITUDE']
df_business.loc[:, 'longitude'] = df_business['LONGITUDE']
df_business.loc[:, 'stars'] = df_business['STARS']
df_business.loc[:, 'review_count'] = df_business['REVIEW_COUNT']
df_business.loc[:, 'is_open'] = df_business['IS_OPEN']
df_business.loc[:, 'attributes'] = df_business['ATTRIBUTES']
df_business.loc[:, 'categories'] = df_business['CATEGORIES']
df_business.loc[:, 'hours'] = df_business['HOURS']

df_business = df_business[['business_id', 'name', 'address', 'city', 'state', 'postal_code', 'latitude', 'longitude', 'stars', 'review_count', 'is_open', 'attributes', 'categories', 'hours']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 df_business = df_business[['BUSINESS_ID', 'NAME', 'REVIEW_COUNT', 'CITY', 'STATE', 'ADDRESS', 'POSTAL_CODE', 'LATITUDE', 'LONGITUDE', 'STARS', 'IS_OPEN', 'ATTRIBUTES', 'CATEGORIES', 'HOURS']]
#       3 df_business.loc[:, 'business_id'] = df_business['BUSINESS_ID']
#       4 df_business.loc[:, 'name'] = df_business['NAME']
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\frame.py:3899, in DataFrame.__getitem__(self, key)
#    3897     if is_iterator(key):
#    3898         key = list(key)
# -> 3899     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3901 # take() does not accept boolean indexers
#    3902 if getattr(indexer, "dtype", None) == bool:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\indexes\base.py:6114, in Index._get_indexer_strict(self, key, axis_name)
#    6111 else:
#    6112     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6114 self._raise_if_missing(keyarr, indexer, axis_name)
#    6116 keyarr = self.take(indexer)
#    6117 if isinstance(key, Index):
#    6118     # GH 42790 - Preserve name from an Index
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\indexes\base.py:6175, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6173     if use_interval_msg:
#    6174         key = list(key)
# -> 6175     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6177 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
#    6178 raise KeyError(f"{not_found} not in index")
#
# KeyError: "None of [Index(['BUSINESS_ID', 'NAME', 'REVIEW_COUNT', 'CITY', 'STATE', 'ADDRESS',\n       'POSTAL_CODE', 'LATITUDE', 'LONGITUDE', 'STARS', 'IS_OPEN',\n       'ATTRIBUTES', 'CATEGORIES', 'HOURS'],\n      dtype='object')] are in the [columns]"

# %%
df_business
# Out:
#                    business_id                      name  \
# 0       Pns2l4eNsfO8kk83dixA6A  Abby Rappoport, LAC, CMQ
# 1       mpf3x-BjTdTEA3yCZrAYPw             The UPS Store
# 2       tUFrWirKiKi_TAnsVWINQQ                    Target
# 3       MTSW4McQd7CbVtyjqoe9mw        St Honore Pastries
# 4       mWMc6_wTdE0EUBKIGXDVfA  Perkiomen Valley Brewery
# ...                        ...                       ...
# 150341  IUQopTMmYQG-qRtBk-8QnA              Binh's Nails
# 150342  c8GjPIOTGVmIemT7j5_SyQ      Wild Birds Unlimited
# 150343  _QAMST-NrQobXduilWEqSw         Claire's Boutique
# 150344  mtGm22y5c2UHNXDFAjaPNw  Cyclery & Fitness Center
# 150345  jV_XOycEzSlTx-65W906pg                   Sic Ink
#
#                                 address           city state postal_code  \
# 0                1616 Chapala St, Ste 2  Santa Barbara   NaN       93101
# 1       87 Grasso Plaza Shopping Center         Affton   NaN       63123
# 2                  5255 E Broadway Blvd         Tucson   NaN       85711
# 3                           935 Race St   Philadelphia    CA       19107
# 4                         101 Walnut St     Green Lane    MO       18054
# ...                                 ...            ...   ...         ...
# 150341                3388 Gateway Blvd       Edmonton    IN     T6J 5H2
# 150342               2813 Bransford Ave      Nashville    DE       37204
# 150343           6020 E 82nd St, Ste 46   Indianapolis    AB       46250
# 150344                     2472 Troy Rd   Edwardsville    AB       62025
# 150345            238 Apollo Beach Blvd   Apollo beach    TN       33572
#
#          latitude   longitude  stars  review_count  is_open  \
# 0       34.426679 -119.711197    5.0           NaN        0
# 1       38.551126  -90.335695    3.0           NaN        1
# 2       32.223236 -110.880452    3.5           NaN        0
# 3       39.955505  -75.155564    4.0           NaN        1
# 4       40.338183  -75.471659    4.5           NaN        1
# ...           ...         ...    ...           ...      ...
# 150341  53.468419 -113.492054    3.0           NaN        1
# 150342  36.115118  -86.766925    4.0           NaN        1
# 150343  39.908707  -86.065088    3.5           NaN        1
# 150344  38.782351  -89.950558    4.0           NaN        1
# 150345  27.771002  -82.394910    4.5           NaN        1
#
#                                                attributes  \
# 0                           {'ByAppointmentOnly': 'True'}
# 1                  {'BusinessAcceptsCreditCards': 'True'}
# 2       {'BikeParking': 'True', 'BusinessAcceptsCredit...
# 3       {'RestaurantsDelivery': 'False', 'OutdoorSeati...
# 4       {'BusinessAcceptsCreditCards': 'True', 'Wheelc...
# ...                                                   ...
# 150341  {'ByAppointmentOnly': 'False', 'RestaurantsPri...
# 150342  {'BusinessAcceptsCreditCards': 'True', 'Restau...
# 150343  {'RestaurantsPriceRange2': '1', 'BusinessAccep...
# 150344  {'BusinessParking': "{'garage': False, 'street...
# 150345  {'WheelchairAccessible': 'True', 'BusinessAcce...
#
#                                                categories  \
# 0       Doctors, Traditional Chinese Medicine, Naturop...
# 1       Shipping Centers, Local Services, Notaries, Ma...
# 2       Department Stores, Shopping, Fashion, Home & G...
# 3       Restaurants, Food, Bubble Tea, Coffee & Tea, B...
# 4                               Brewpubs, Breweries, Food
# ...                                                   ...
# 150341                         Nail Salons, Beauty & Spas
# 150342  Pets, Nurseries & Gardening, Pet Stores, Hobby...
# 150343  Shopping, Jewelry, Piercing, Toy Stores, Beaut...
# 150344  Fitness/Exercise Equipment, Eyewear & Optician...
# 150345  Beauty & Spas, Permanent Makeup, Piercing, Tattoo
#
#                                                     hours
# 0                                                     NaN
# 1       {'Monday': '0:0-0:0', 'Tuesday': '8:0-18:30', ...
# 2       {'Monday': '8:0-22:0', 'Tuesday': '8:0-22:0', ...
# 3       {'Monday': '7:0-20:0', 'Tuesday': '7:0-20:0', ...
# 4       {'Wednesday': '14:0-22:0', 'Thursday': '16:0-2...
# ...                                                   ...
# 150341  {'Monday': '10:0-19:30', 'Tuesday': '10:0-19:3...
# 150342  {'Monday': '9:30-17:30', 'Tuesday': '9:30-17:3...
# 150343                                                NaN
# 150344  {'Monday': '9:0-20:0', 'Tuesday': '9:0-20:0', ...
# 150345  {'Tuesday': '12:0-19:0', 'Wednesday': '12:0-19...
#
# [150346 rows x 14 columns]

# %%
filtro = ['Restaurant']

# Filtrar el DataFrame solo para las filas donde 'categories' no es NaN
df_filtered = df_business.dropna(subset=['categories'])

# Luego, aplicar el filtro
restaurante = df_filtered[df_filtered['categories'].str.contains('|'.join(filtro), regex=True)]

# %%
restaurante
# Out:
#                    business_id                           name  \
# 3       MTSW4McQd7CbVtyjqoe9mw             St Honore Pastries
# 5       CF33F8-E6oudUQ46HnavjQ                 Sonic Drive-In
# 8       k0hlBqXX-Bt0vf1op7Jr1w          Tsevi's Pub And Grill
# 9       bBDDEgkFA1Otx9Lfe7BZUQ                 Sonic Drive-In
# 11      eEOYSgkmpB90uNA7lDOMRA          Vietnamese Food Truck
# ...                        ...                            ...
# 150325  l9eLGG9ZKpLJzboZq-9LRQ                           Wawa
# 150327  cM6V90ExQD6KMSU3rRB5ZA              Dutch Bros Coffee
# 150336  WnT9NIzQgLlILjPT0kEcsQ  Adelita Taqueria & Restaurant
# 150339  2O2K6SXPWv56amqxCECd4w                   The Plum Pit
# 150340  hn9Toz3s-Ei3uZPt7esExA          West Side Kebab House
#
#                       address             city state postal_code   latitude  \
# 3                 935 Race St     Philadelphia    CA       19107  39.955505
# 5               615 S Main St     Ashland City    AZ       37015  36.269593
# 8           8025 Mackenzie Rd           Affton    TN       63123  38.565165
# 9         2312 Dickerson Pike        Nashville    MO       37207  36.208102
# 11                        NaN        Tampa Bay    MO       33602  27.955269
# ...                       ...              ...   ...         ...        ...
# 150325        19 N Bishop Ave  Clifton Heights    TN       19018  39.925656
# 150327    1181 N Milwaukee St            Boise    ID       83704  43.615401
# 150336          1108 S 9th St     Philadelphia    MO       19147  39.935982
# 150339        4405 Pennell Rd            Aston    PA       19014  39.856185
# 150340  2470 Guardian Road NW         Edmonton    NJ     T5T 1K8  53.509649
#
#          longitude  stars  review_count  is_open  \
# 3       -75.155564    4.0           NaN        1
# 5       -87.058943    2.0           NaN        1
# 8       -90.321087    3.0           NaN        0
# 9       -86.768170    1.5           NaN        1
# 11      -82.456320    4.0           NaN        1
# ...            ...    ...           ...      ...
# 150325  -75.310344    3.0           NaN        1
# 150327 -116.284689    4.0           NaN        1
# 150336  -75.158665    4.5           NaN        1
# 150339  -75.427725    4.5           NaN        1
# 150340 -113.675999    4.5           NaN        0
#
#                                                attributes  \
# 3       {'RestaurantsDelivery': 'False', 'OutdoorSeati...
# 5       {'BusinessParking': 'None', 'BusinessAcceptsCr...
# 8       {'Caters': 'True', 'Alcohol': "u'full_bar'", '...
# 9       {'RestaurantsAttire': "'casual'", 'Restaurants...
# 11      {'Alcohol': "'none'", 'OutdoorSeating': 'None'...
# ...                                                   ...
# 150325  {'BikeParking': 'True', 'BusinessAcceptsCredit...
# 150327  {'WiFi': "'free'", 'RestaurantsGoodForGroups':...
# 150336  {'WheelchairAccessible': 'False', 'Restaurants...
# 150339  {'RestaurantsDelivery': 'False', 'BusinessAcce...
# 150340  {'Ambience': "{'touristy': False, 'hipster': F...
#
#                                                categories  \
# 3       Restaurants, Food, Bubble Tea, Coffee & Tea, B...
# 5       Burgers, Fast Food, Sandwiches, Food, Ice Crea...
# 8       Pubs, Restaurants, Italian, Bars, American (Tr...
# 9       Ice Cream & Frozen Yogurt, Fast Food, Burgers,...
# 11             Vietnamese, Food, Restaurants, Food Trucks
# ...                                                   ...
# 150325  Restaurants, Sandwiches, Convenience Stores, C...
# 150327  Cafes, Juice Bars & Smoothies, Coffee & Tea, R...
# 150336                               Restaurants, Mexican
# 150339  Restaurants, Comfort Food, Food, Food Trucks, ...
# 150340                        Middle Eastern, Restaurants
#
#                                                     hours
# 3       {'Monday': '7:0-20:0', 'Tuesday': '7:0-20:0', ...
# 5       {'Monday': '0:0-0:0', 'Tuesday': '6:0-22:0', '...
# 8                                                     NaN
# 9       {'Monday': '0:0-0:0', 'Tuesday': '6:0-21:0', '...
# 11      {'Monday': '11:0-14:0', 'Tuesday': '11:0-14:0'...
# ...                                                   ...
# 150325  {'Monday': '0:0-0:0', 'Tuesday': '0:0-0:0', 'W...
# 150327  {'Monday': '0:0-0:0', 'Tuesday': '0:0-17:0', '...
# 150336  {'Monday': '11:0-22:0', 'Tuesday': '11:0-22:0'...
# 150339  {'Monday': '0:0-0:0', 'Tuesday': '0:0-0:0', 'W...
# 150340  {'Monday': '11:0-22:0', 'Tuesday': '11:0-22:0'...
#
# [52286 rows x 14 columns]

# %%
restaurante.to_csv('data/Yelp/restaurante.csv')

# %%
df_business.to_csv('data/Yelp/business.csv',index = False)

# %% [markdown]
# ## tip.json

# %%
json_objects=[]

with open('data/Yelp/tip.json', 'r',encoding='utf-8') as f:
    for line in f:
        json_objects.append(json.loads(line))
df_tip = pd.DataFrame(json_objects)

# %%
df_tip
# Out:
#                        user_id             business_id  \
# 0       AGNUgVwnZUey3gcPCJ76iw  3uLgwr0qeCNMjKenHJwPGQ
# 1       NBN4MgHP9D3cw--SnauTkA  QoezRbYQncpRqyrLH6Iqjg
# 2       -copOvldyKh1qr-vzkDEvw  MYoRNLb5chwjQe3c_k37Gg
# 3       FjMQVZjSqY8syIO-53KFKw  hV-bABTK-glh5wj31ps_Jw
# 4       ld0AperBXk1h6UbqmM80zw  _uN0OudeJ3Zl_tf6nxg5ww
# ...                        ...                     ...
# 908910  eYodOTF8pkqKPzHkcxZs-Q  3lHTewuKFt5IImbXJoFeDQ
# 908911  1uxtQAuJ2T5Xwa_wp7kUnA  OaGf0Dp56ARhQwIDT90w_g
# 908912  v48Spe6WEpqehsF2xQADpg  hYnMeAO77RGyTtIzUSKYzQ
# 908913  ckqKGM2hl7I9Chp5IpAhkw  s2eyoTuJrcP7I_XyjdhUHQ
# 908914  4tF1CWdMxvvwpUIgGsDygA  _cb1Vg1NIWry8UA0jyuXnQ
#
#                                                      text  \
# 0                          Avengers time with the ladies.
# 1       They have lots of good deserts and tasty cuban...
# 2                  It's open even when you think it isn't
# 3                               Very decent fried chicken
# 4                  Appetizers.. platter special for lunch
# ...                                                   ...
# 908910              Disappointed in one of your managers.
# 908911                            Great food and service.
# 908912                                Love their Cubans!!
# 908913                            Great pizza great price
# 908914                  Food is good value but a bit hot!
#
#                        date  compliment_count
# 0       2012-05-18 02:17:21                 0
# 1       2013-02-05 18:35:10                 0
# 2       2013-08-18 00:56:08                 0
# 3       2017-06-27 23:05:38                 0
# 4       2012-10-06 19:43:09                 0
# ...                     ...               ...
# 908910  2021-09-11 19:18:57                 0
# 908911  2021-10-30 11:54:36                 0
# 908912  2021-11-05 13:18:56                 0
# 908913  2021-11-20 16:11:44                 0
# 908914  2021-12-07 22:30:00                 0
#
# [908915 rows x 5 columns]

# %% [markdown]
# ## review.json

# %%
def abrir_Archivo_json(archivo):
    merged_data = []  # Lista para almacenar los objetos JSON combinados

    with open(archivo,encoding = 'utf-8') as file:
        for line in file:
            try:
                obj = json.loads(line)
                merged_data.append(obj)
            except json.JSONDecodeError as e:
                print(f"Error al decodificar JSON en el archivo {archivo}: {str(e)}")

    df = pd.DataFrame(merged_data)  # Crear DataFrame a partir de los objetos JSON
    return df

# %%
archivo = ('data/Yelp/review.json')
review=abrir_Archivo_json(archivo)

# %%
review
# Out:
#                       review_id                 user_id  \
# 0        KU_O5udG6zpxOg-VcAEodg  mh_-eMZ6K5RLWhZyISBhwA
# 1        BiTunyQ73aT9WBnpR9DZGw  OyoGAe7OKpv6SyGZT5g77Q
# 2        saUsX_uimxRlCVr67Z4Jig  8g_iMtfSiwikVnbP2etR0A
# 3        AqPFMleE6RsU23_auESxiA  _7bHUi9Uuf5__HHc_Q8guQ
# 4        Sx8TMOWLNuJBWer-0pcmoA  bcjbaE6dDog4jkNY91ncLQ
# ...                         ...                     ...
# 6990275  H0RIamZu0B0Ei0P4aeh3sQ  qskILQ3k0I_qcCMI-k6_QQ
# 6990276  shTPgbgdwTHSuU67mGCmZQ  Zo0th2m8Ez4gLSbHftiQvg
# 6990277  YNfNhgZlaaCO5Q_YJR4rEw  mm6E4FbCMwJmb7kPDZ5v2Q
# 6990278  i-I4ZOhoX70Nw5H0FwrQUA  YwAMC-jvZ1fvEUum6QkEkw
# 6990279  RwcKOdEuLRHNJe4M9-qpqg  6JehEvdoCvZPJ_XIxnzIIw
#
#                     business_id  stars  useful  funny  cool  \
# 0        XQfwVwDr-v0ZS3_CbbE5Xw    3.0       0      0     0
# 1        7ATYjTIgM3jUlt4UM3IypQ    5.0       1      0     1
# 2        YjUWPpI6HXG530lwP-fb2A    3.0       0      0     0
# 3        kxX2SOes4o-D3ZQBkiMRfA    5.0       1      0     1
# 4        e4Vwtrqf-wpJfwesgvdgxQ    4.0       1      0     1
# ...                         ...    ...     ...    ...   ...
# 6990275  jals67o91gcrD4DC81Vk6w    5.0       1      2     1
# 6990276  2vLksaMmSEcGbjI5gywpZA    5.0       2      1     2
# 6990277  R1khUUxidqfaJmcpmGd4aw    4.0       1      0     0
# 6990278  Rr9kKArrMhSLVE9a53q-aA    5.0       1      0     0
# 6990279  VAeEXLbEcI9Emt9KGYq9aA    3.0      10      3     7
#
#                                                       text  \
# 0        If you decide to eat here, just be aware it is...
# 1        I've taken a lot of spin classes over the year...
# 2        Family diner. Had the buffet. Eclectic assortm...
# 3        Wow!  Yummy, different,  delicious.   Our favo...
# 4        Cute interior and owner (?) gave us tour of up...
# ...                                                    ...
# 6990275  Latest addition to services from ICCU is Apple...
# 6990276  This spot offers a great, affordable east week...
# 6990277  This Home Depot won me over when I needed to g...
# 6990278  For when I'm feeling like ignoring my calorie-...
# 6990279  Located in the 'Walking District' in Nashville...
#
#                         date
# 0        2018-07-07 22:09:11
# 1        2012-01-03 15:28:18
# 2        2014-02-05 20:30:30
# 3        2015-01-04 00:01:03
# 4        2017-01-14 20:54:15
# ...                      ...
# 6990275  2014-12-17 21:45:20
# 6990276  2021-03-31 16:55:10
# 6990277  2019-12-30 03:56:30
# 6990278  2022-01-19 18:59:27
# 6990279  2018-01-02 22:50:47
#
# [6990280 rows x 9 columns]

# %%
restaurante_review = pd.merge(restaurante,review, on = 'business_id',how='inner')

# %%
restaurante_review
# Out:
#                     business_id                   name                address  \
# 0        MTSW4McQd7CbVtyjqoe9mw     St Honore Pastries            935 Race St
# 1        MTSW4McQd7CbVtyjqoe9mw     St Honore Pastries            935 Race St
# 2        MTSW4McQd7CbVtyjqoe9mw     St Honore Pastries            935 Race St
# 3        MTSW4McQd7CbVtyjqoe9mw     St Honore Pastries            935 Race St
# 4        MTSW4McQd7CbVtyjqoe9mw     St Honore Pastries            935 Race St
# ...                         ...                    ...                    ...
# 4724679  hn9Toz3s-Ei3uZPt7esExA  West Side Kebab House  2470 Guardian Road NW
# 4724680  hn9Toz3s-Ei3uZPt7esExA  West Side Kebab House  2470 Guardian Road NW
# 4724681  hn9Toz3s-Ei3uZPt7esExA  West Side Kebab House  2470 Guardian Road NW
# 4724682  hn9Toz3s-Ei3uZPt7esExA  West Side Kebab House  2470 Guardian Road NW
# 4724683  hn9Toz3s-Ei3uZPt7esExA  West Side Kebab House  2470 Guardian Road NW
#
#                  city state postal_code   latitude   longitude  stars_x  \
# 0        Philadelphia    CA       19107  39.955505  -75.155564      4.0
# 1        Philadelphia    CA       19107  39.955505  -75.155564      4.0
# 2        Philadelphia    CA       19107  39.955505  -75.155564      4.0
# 3        Philadelphia    CA       19107  39.955505  -75.155564      4.0
# 4        Philadelphia    CA       19107  39.955505  -75.155564      4.0
# ...               ...   ...         ...        ...         ...      ...
# 4724679      Edmonton    NJ     T5T 1K8  53.509649 -113.675999      4.5
# 4724680      Edmonton    NJ     T5T 1K8  53.509649 -113.675999      4.5
# 4724681      Edmonton    NJ     T5T 1K8  53.509649 -113.675999      4.5
# 4724682      Edmonton    NJ     T5T 1K8  53.509649 -113.675999      4.5
# 4724683      Edmonton    NJ     T5T 1K8  53.509649 -113.675999      4.5
#
#          review_count  ...                                         categories  \
# 0                 NaN  ...  Restaurants, Food, Bubble Tea, Coffee & Tea, B...
# 1                 NaN  ...  Restaurants, Food, Bubble Tea, Coffee & Tea, B...
# 2                 NaN  ...  Restaurants, Food, Bubble Tea, Coffee & Tea, B...
# 3                 NaN  ...  Restaurants, Food, Bubble Tea, Coffee & Tea, B...
# 4                 NaN  ...  Restaurants, Food, Bubble Tea, Coffee & Tea, B...
# ...               ...  ...                                                ...
# 4724679           NaN  ...                        Middle Eastern, Restaurants
# 4724680           NaN  ...                        Middle Eastern, Restaurants
# 4724681           NaN  ...                        Middle Eastern, Restaurants
# 4724682           NaN  ...                        Middle Eastern, Restaurants
# 4724683           NaN  ...                        Middle Eastern, Restaurants
#
#                                                      hours  \
# 0        {'Monday': '7:0-20:0', 'Tuesday': '7:0-20:0', ...
# 1        {'Monday': '7:0-20:0', 'Tuesday': '7:0-20:0', ...
# 2        {'Monday': '7:0-20:0', 'Tuesday': '7:0-20:0', ...
# 3        {'Monday': '7:0-20:0', 'Tuesday': '7:0-20:0', ...
# 4        {'Monday': '7:0-20:0', 'Tuesday': '7:0-20:0', ...
# ...                                                    ...
# 4724679  {'Monday': '11:0-22:0', 'Tuesday': '11:0-22:0'...
# 4724680  {'Monday': '11:0-22:0', 'Tuesday': '11:0-22:0'...
# 4724681  {'Monday': '11:0-22:0', 'Tuesday': '11:0-22:0'...
# 4724682  {'Monday': '11:0-22:0', 'Tuesday': '11:0-22:0'...
# 4724683  {'Monday': '11:0-22:0', 'Tuesday': '11:0-22:0'...
#
#                       review_id                 user_id stars_y useful  funny  \
# 0        BXQcBN0iAi1lAUxibGLFzA  6_SpY41LIHZuIaiDs5FMKA     4.0      0      0
# 1        uduvUCvi9w3T2bSGivCfXg  tCXElwhzekJEH6QJe3xs7Q     4.0      3      1
# 2        a0vwPOqDXXZuJkbBW2356g  WqfKtI-aGMmvbA9pPUxNQQ     5.0      0      0
# 3        MKNp_CdR2k2202-c8GN5Dw  3-1va0IQfK-9tUMzfHWfTA     5.0      5      0
# 4        D1GisLDPe84Rrk_R4X2brQ  EouCKoDfzaVG0klEgdDvCQ     4.0      2      1
# ...                         ...                     ...     ...    ...    ...
# 4724679  Lu5jvEjtPFUa-z9IzsMv7w  CnzkseV3WTE5W8o5Pa7fJA     5.0      2      0
# 4724680  WbpiPPmiZYfDutO46AOJrA  ZZQ0g2DnXw3iXv5LgGeY7Q     5.0      0      0
# 4724681  cdwE0S1ONp1ypsTN1e3mLg  C6jwPqUk8VB0FuZO7y2MHA     5.0      1      1
# 4724682  uXnne-Ui2pvObTtT3MUYxg  9b0pmwxxGIuXKXIJh__mlQ     4.0      0      0
# 4724683  kmjmijBnLpPJDs47GrmZCQ  eSXnEIxNm39eFgvG6TtRRg     5.0      0      0
#
#          cool                                               text  \
# 0           1  This is nice little Chinese bakery in the hear...
# 1           2  This is the bakery I usually go to in Chinatow...
# 2           0  A delightful find in Chinatown! Very clean, an...
# 3           5  I ordered a graduation cake for my niece and i...
# 4           1  HK-STYLE MILK TEA:  FOUR STARS\n\nNot quite su...
# ...       ...                                                ...
# 4724679     2  YES.\n\nI have been to 2 other comparable Midd...
# 4724680     0  We had the beef plate medium rare that was mou...
# 4724681     1  Excellent Mediterranean food! Always cooked to...
# 4724682     0  This was my first visit to West Side Kebab Hou...
# 4724683     1  Walked in on a Sunday afternoon to an empty re...
#
#                         date
# 0        2014-05-26 01:09:53
# 1        2013-10-05 15:19:06
# 2        2013-10-25 01:34:57
# 3        2018-05-20 17:58:57
# 4        2013-10-25 02:31:35
# ...                      ...
# 4724679  2017-03-13 19:47:08
# 4724680  2018-04-14 23:41:03
# 4724681  2018-06-19 02:02:41
# 4724682  2017-03-24 01:46:31
# 4724683  2018-02-18 22:01:43
#
# [4724684 rows x 22 columns]

# %%
#Se crea un filtro de estados
'''
Florida = FL
Georgia = GA
Alabama = AL
Carolina del sur = SC
Carolina del Norte = NC

'''

estados = ['FL','GA','AL','NC','SC']


# Filtrar el DataFrame solo para las filas donde 'state' no es NaN
df_estados= restaurante_review.dropna(subset=['state'])

# Luego, aplicar el filtro
df_restaurante_review = df_estados[df_estados['state'].str.contains('|'.join(estados), regex=True)]

# %%
df_restaurante_review
# Out:
#                     business_id                           name  \
# 162      0bPLkL0QhhPO5kt1_EXmNQ           Zio's Italian Market
# 163      0bPLkL0QhhPO5kt1_EXmNQ           Zio's Italian Market
# 164      0bPLkL0QhhPO5kt1_EXmNQ           Zio's Italian Market
# 165      0bPLkL0QhhPO5kt1_EXmNQ           Zio's Italian Market
# 166      0bPLkL0QhhPO5kt1_EXmNQ           Zio's Italian Market
# ...                         ...                            ...
# 4723205  esBGrrmuZzSiECyRBoKvvA  Colony Grill - St. Petersburg
# 4723206  esBGrrmuZzSiECyRBoKvvA  Colony Grill - St. Petersburg
# 4723207  esBGrrmuZzSiECyRBoKvvA  Colony Grill - St. Petersburg
# 4723208  esBGrrmuZzSiECyRBoKvvA  Colony Grill - St. Petersburg
# 4723209  esBGrrmuZzSiECyRBoKvvA  Colony Grill - St. Petersburg
#
#                  address            city state postal_code   latitude  \
# 162        2575 E Bay Dr           Largo    FL       33771  27.916116
# 163        2575 E Bay Dr           Largo    FL       33771  27.916116
# 164        2575 E Bay Dr           Largo    FL       33771  27.916116
# 165        2575 E Bay Dr           Largo    FL       33771  27.916116
# 166        2575 E Bay Dr           Largo    FL       33771  27.916116
# ...                  ...             ...   ...         ...        ...
# 4723205  670 Central Ave  St. Petersburg    FL       33701  27.770872
# 4723206  670 Central Ave  St. Petersburg    FL       33701  27.770872
# 4723207  670 Central Ave  St. Petersburg    FL       33701  27.770872
# 4723208  670 Central Ave  St. Petersburg    FL       33701  27.770872
# 4723209  670 Central Ave  St. Petersburg    FL       33701  27.770872
#
#          longitude  stars_x  review_count  ...  \
# 162     -82.760461      4.5           NaN  ...
# 163     -82.760461      4.5           NaN  ...
# 164     -82.760461      4.5           NaN  ...
# 165     -82.760461      4.5           NaN  ...
# 166     -82.760461      4.5           NaN  ...
# ...            ...      ...           ...  ...
# 4723205 -82.643069      4.5           NaN  ...
# 4723206 -82.643069      4.5           NaN  ...
# 4723207 -82.643069      4.5           NaN  ...
# 4723208 -82.643069      4.5           NaN  ...
# 4723209 -82.643069      4.5           NaN  ...
#
#                                                 categories  \
# 162            Food, Delis, Italian, Bakeries, Restaurants
# 163            Food, Delis, Italian, Bakeries, Restaurants
# 164            Food, Delis, Italian, Bakeries, Restaurants
# 165            Food, Delis, Italian, Bakeries, Restaurants
# 166            Food, Delis, Italian, Bakeries, Restaurants
# ...                                                    ...
# 4723205  Bars, Beer Bar, Nightlife, Wine Bars, Pizza, R...
# 4723206  Bars, Beer Bar, Nightlife, Wine Bars, Pizza, R...
# 4723207  Bars, Beer Bar, Nightlife, Wine Bars, Pizza, R...
# 4723208  Bars, Beer Bar, Nightlife, Wine Bars, Pizza, R...
# 4723209  Bars, Beer Bar, Nightlife, Wine Bars, Pizza, R...
#
#                                                      hours  \
# 162      {'Monday': '10:0-18:0', 'Tuesday': '10:0-20:0'...
# 163      {'Monday': '10:0-18:0', 'Tuesday': '10:0-20:0'...
# 164      {'Monday': '10:0-18:0', 'Tuesday': '10:0-20:0'...
# 165      {'Monday': '10:0-18:0', 'Tuesday': '10:0-20:0'...
# 166      {'Monday': '10:0-18:0', 'Tuesday': '10:0-20:0'...
# ...                                                    ...
# 4723205  {'Monday': '11:30-23:0', 'Tuesday': '11:30-23:...
# 4723206  {'Monday': '11:30-23:0', 'Tuesday': '11:30-23:...
# 4723207  {'Monday': '11:30-23:0', 'Tuesday': '11:30-23:...
# 4723208  {'Monday': '11:30-23:0', 'Tuesday': '11:30-23:...
# 4723209  {'Monday': '11:30-23:0', 'Tuesday': '11:30-23:...
#
#                       review_id                 user_id stars_y useful  funny  \
# 162      oTTuahWNWzX_018P6O6_2g  z1Dfj8kz3KCArkXaIyaBIA     1.0      6      1
# 163      R7DC4sHDcklrk1s1K93FDA  HvgKiuV36e9SzNqeA5zOfA     4.0      0      0
# 164      8kDLAf-muASQfs5zDXpiyw  7BhiY0D84Lj04kjEWn5fIQ     5.0      0      0
# 165      KupYGAYqAKVLP9cspQ-9TQ  0EjWviHaYwdaMaD8VBOHWA     5.0      1      1
# 166      hl4dIQIKphmMWH59WrO5-g  E47ejL3krT1wG8NvgtJDgw     4.0      2      1
# ...                         ...                     ...     ...    ...    ...
# 4723205  wrqWvAdWD9YpB-1C2Xnp4w  E2uJ62_uEUu5wz2EnZ9CgA     2.0      0      4
# 4723206  TvXYbjdP1yiVqV4ixgKWsQ  8aE275qBmEVUjb_nrE65CQ     5.0      1      0
# 4723207  dMhZvWaJAB957YIHjwKXWA  4wMvgdEVpFLCIhFANNBvGA     5.0      1      0
# 4723208  mTgQG-wCDdAW8ahnukggJg  mbIemu2trEjtn8viGHD3dA     5.0      0      0
# 4723209  x3Fel31bmcK1T6JzfcWHig  rDtA_KBbjnPjsKDT0-itgA     5.0      1      0
#
#          cool                                               text  \
# 162         0  The worst Chicken Parm. Sandwich I've ever eat...
# 163         0  Zio's, previously known as Cesarina's is a lar...
# 164         0  As an update to my previous review, we had tri...
# 165         0  The little deli belongs in little Italy. Wonde...
# 166         1  Very good food for very good prices. I had the...
# ...       ...                                                ...
# 4723205     0  Very small menu.  Pizza is the ONLY food item ...
# 4723206     0  This place is great! The space is big with a n...
# 4723207     0  So first looking at the menu for this place yo...
# 4723208     0  I lived in CT for 10 years and CT style pizza ...
# 4723209     0  The pizza was thin crust and light. Great spot...
#
#                         date
# 162      2014-05-25 21:52:30
# 163      2018-07-26 16:25:04
# 164      2018-04-28 00:32:12
# 165      2015-08-30 18:56:08
# 166      2011-10-28 20:06:00
# ...                      ...
# 4723205  2021-11-04 02:43:27
# 4723206  2021-11-04 13:28:42
# 4723207  2022-01-02 03:35:40
# 4723208  2021-11-26 22:55:22
# 4723209  2021-11-14 16:53:07
#
# [824900 rows x 22 columns]

# %%
restaurante_review.to_csv('data/Yelp/restaurante_review.csv',index = False)

# %% [markdown]
# # Restaurante_review
# Se trabaja sobre el DataFrame que almacena las review de los restaurantes

# %%
df_restaurante_review = pd.read_csv('data/Yelp/df_restaurante_review')

# %%
df_restaurante_review.sample(5)
# Out:
#                    business_id                          name  \
# 63033   u7_3L1NBWgxhBM_B-cmmnA                Pizzeria Vetri
# 657455  y7WPOc2_vCoBkwK3xPJ8XA                  Unit Su Vege
# 227478  0oSqhCkK1qCY3I7-o0ZR1A  Garbanzo Mediterranean Fresh
# 598863  bCZFb9v6OQaNTgupVw9WEg         Fulin's Asian Cuisine
# 695373  dgyKoIYEYrmRK_hktWBZdA                   The Getaway
#
#                           address              city state postal_code  \
# 63033          1939 Callowhill St      Philadelphia    FL       19130
# 657455  2000 Hamilton St, Ste 106      Philadelphia    FL       19130
# 227478          8143 Maryland Ave           Clayton    FL       63105
# 598863          206 N Anderson Ln    Hendersonville    FL       37075
# 695373         13090 Gandy Blvd N  Saint Petersburg    FL       33702
#
#          latitude  longitude  stars_x  review_count  ...  stars_y useful  \
# 63033   39.960888 -75.171213      4.0           NaN  ...      4.0      1
# 657455  39.962183 -75.172190      4.5           NaN  ...      5.0      1
# 227478  38.652585 -90.343073      4.0           NaN  ...      5.0      1
# 598863  36.322611 -86.597730      3.5           NaN  ...      1.0      0
# 695373  27.871061 -82.611473      3.0           NaN  ...      1.0      0
#
#        funny cool                                               text  \
# 63033      0    1  One would think with Pizzeria Vetri being so c...
# 657455     0    1  Excellent vegan/vegetarian food.  We ordered t...
# 227478     0    0  I told the staff  I had never been in before a...
# 598863     0    0  I've eaten at Fulins for many years and the fo...
# 695373     0    0  This is a great location , right on the water ...
#
#                        date  year  month  day  hour
# 63033   2014-08-12 16:55:31  2014      8   12    16
# 657455  2020-03-01 01:05:35  2020      3    1     1
# 227478  2021-08-08 17:26:06  2021      8    8    17
# 598863  2016-04-01 23:49:02  2016      4    1    23
# 695373  2017-12-24 18:26:50  2017     12   24    18
#
# [5 rows x 26 columns]

# %%
# Convertir la columna 'date' al formato de fecha
df_restaurante_review['date'] = pd.to_datetime(df_restaurante_review['date'])

# Agregar una nueva columna llamada 'year' que muestra el año de la columna 'date'
df_restaurante_review['year'] = df_restaurante_review['date'].dt.year
# Agregar una nueva columna llamada 'month' que muestra el mes de la columna 'date'
df_restaurante_review['month'] = df_restaurante_review['date'].dt.month
## Agregar una nueva columna llamada 'day' que muestra el dia de la columna 'date'
df_restaurante_review['day'] = df_restaurante_review['date'].dt.day

# %%
#agregar una nueva columa llamada 'hopur' que muestra la hora de la columna 'date'
df_restaurante_review['hour'] = df_restaurante_review['date'].dt.hour

# %%
df_restaurante_review.sample(10)
# Out:
#                    business_id                                name  \
# 133012  vOXoM9W8-CpHbZUiGbL3dw                           Pho Queen
# 572601  LwX2vbzttWYAdoBoVtfvRg                      City Tap House
# 631476  LfaaI92M2UtiT3JriY_FWQ               El Paso Mexican Grill
# 500283  8P8HIysyyGbG8_94cG1Jyg                         Entree BYOB
# 509560  cRvoGf7krkQKF85UvOQo_A         Chihuahua's Cantina & Grill
# 130052  AVf4RO3bh2AAoZeCiPTQNg    Hattie B's Hot Chicken - Melrose
# 732356  vRle3eQO4T767azL09rFnA                 Lodge On The Desert
# 614536  dGeXdSMah56gEHwZNaRQKA               Juan's Flying Burrito
# 551713  Ah0ZcMgzzigx-qLXznni3A                      Bighorn Tavern
# 329573  Qo14LZITJ4fIhSdqOVsm6w  Pat O'Brien's Courtyard Restaurant
#
#                                      address          city state postal_code  \
# 133012                 29000 US Highway 19 N    Clearwater    FL       33761
# 572601  3925 Walnut St, Fl 2, Radian Balcony  Philadelphia    FL       19104
# 631476                     601 Veterans Blvd      Metairie    FL       70005
# 500283                         1608 South St  Philadelphia    FL       19146
# 509560             7111 S Virginia St, Ste C          Reno    FL       89511
# 130052                        2222 8th Ave S     Nashville    FL       37204
# 732356                    306 N Alvernon Way        Tucson    FL       85711
# 614536                 4724 S Carrollton Ave   New Orleans    FL       70119
# 551713                  1325 W 7th St, Ste G          Reno    FL       89503
# 329573                        624 Bourbon St   New Orleans    FL       70130
#
#          latitude   longitude  stars_x  review_count  ...  stars_y useful  \
# 133012  28.035875  -82.739051      3.5           NaN  ...      5.0      0
# 572601  39.954309  -75.201352      3.5           NaN  ...      1.0      0
# 631476  30.001731  -90.128735      3.0           NaN  ...      3.0      1
# 500283  39.944011  -75.169140      4.5           NaN  ...      5.0      0
# 509560  39.461741 -119.782225      4.0           NaN  ...      5.0      0
# 130052  36.129008  -86.777565      4.5           NaN  ...      5.0      1
# 732356  32.226041 -110.908959      3.5           NaN  ...      4.0      0
# 614536  29.973816  -90.100877      3.5           NaN  ...      3.0      1
# 551713  39.531079 -119.834014      4.5           NaN  ...      5.0      0
# 329573  29.958188  -90.065854      4.0           NaN  ...      3.0      0
#
#        funny cool                                               text  \
# 133012     0    0  Awesome authentic Vietnamese restaurant in the...
# 572601     0    0  I was so offended by my recent experience at c...
# 631476     0    0  We have been going on average every two weeks....
# 500283     0    0  We had a party of eight for Restuarant week. O...
# 509560     0    0  My favorite Mexican restuarant by a long way, ...
# 130052     0    1  We were on a cross country road trip from Pens...
# 732356     0    0  Excellent choice of fresh, local ingredients a...
# 614536     0    0  Juan's Flying Burrito: great food, slow servic...
# 551713     0    0  Food was tasty.  Space is unassuming.  Service...
# 329573     0    0  The Hurricane tasted like a refreshing cool ai...
#
#                        date  year  month  day  hour
# 133012  2018-02-16 18:17:12  2018      2   16    18
# 572601  2016-01-23 20:34:02  2016      1   23    20
# 631476  2016-07-22 00:18:32  2016      7   22     0
# 500283  2015-01-21 03:39:56  2015      1   21     3
# 509560  2018-02-18 05:11:29  2018      2   18     5
# 130052  2019-04-17 22:16:24  2019      4   17    22
# 732356  2011-09-15 17:48:41  2011      9   15    17
# 614536  2010-03-29 19:32:28  2010      3   29    19
# 551713  2019-07-28 22:31:13  2019      7   28    22
# 329573  2015-08-27 21:01:23  2015      8   27    21
#
# [10 rows x 26 columns]

# %%
df_restaurante_review.to_csv('data/Yelp/df_restaurante_review',index = False)
